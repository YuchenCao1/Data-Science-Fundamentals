# %% [markdown]
# # Worksheet 11
#
# Name: Zihan Li, Jingbo Wang, Yuchen Chao
# UID: U83682995, U04536921, U51424608
#
# ### Topics
#
# - Latent Semantic Analysis
#
# ### Latent Semantic Analysis
#
# In this section we will fetch news articles from 3 different categories. We will perform Tfidf vectorization on the corpus of documents and use SVD to represent our corpus in the feature space of topics that we've uncovered from SVD. We will attempt to cluster the documents into 3 clusters as we vary the number of singular vectors we use to represent the corpus, and compare the output to the clustering created by the news article categories. Do we end up with a better clustering the more singular vectors we use?

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize, sent_tokenize

# Fetch news articles
categories = ['comp.os.ms-windows.misc', 'sci.space', 'rec.sport.baseball']
news_data = fetch_20newsgroups(subset='train', categories=categories)

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(stop_words='english', min_df=4, max_df=0.8)

# Preprocess and stem the data
stemmed_data = [" ".join(SnowballStemmer("english", ignore_stopwords=True).stem(word)
                         for sent in sent_tokenize(message)
                         for word in word_tokenize(sent))
                for message in news_data.data]

# Vectorize the stemmed data
dtm = vectorizer.fit_transform(stemmed_data)

# Perform SVD on the DTM
u, s, vt = np.linalg.svd(dtm.toarray(), full_matrices=False)  # Use toarray() for dense SVD

# Plot singular values to inspect the decay
plt.figure(figsize=(10, 6))
plt.xlim([0, 50])
plt.plot(range(1, len(s) + 1), s)
plt.title('Singular Values')
plt.xlabel('Singular Value Index')
plt.ylabel('Singular Value Magnitude')
plt.show()

# Evaluate clustering performance as we vary the number of singular vectors
agreement_scores = []
for k in range(1, 25):
    vectorsk = u[:, :k] @ np.diag(s[:k])
    kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=100, n_init=10, random_state=0)
    labels_k = kmeans.fit_predict(vectorsk)
    agreement_scores.append(metrics.v_measure_score(labels_k, news_data.target))

# Plot the agreement (V-measure) scores
plt.figure(figsize=(10, 6))
plt.plot(range(1, 25), agreement_scores)
plt.title('Clustering Agreement vs. Number of Principal Components')
plt.xlabel('Number of Principal Components')
plt.ylabel('V-measure Score')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /Users/yuchencao/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yuchencao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Embeddings
#
# The data comes from the [Yelp Dataset](https://www.yelp.com/dataset). Each line is a review that consists of a label (0 for negative reviews and 1 for positive reviews) and a set of words.
#
# ```
# 1 i will never forget this single breakfast experience in mad...
# 0 the search for decent chinese takeout in madison continues ...
# 0 sorry but me julio fell way below the standard even for med...
# 1 so this is the kind of food that will kill you so there s t...
# ```
#
# In order to transform the set of words into vectors, we will rely on a method of feature engineering called word embeddings (Tfidf is one way to get these embeddings). Rather than simply indicating which words are present, word embeddings represent each word by "embedding" it in a low-dimensional vector space which may carry more information about the semantic meaning of the word. (for example in this space, the words "King" and "Queen" would be close).
#
# `word2vec.txt` contains the `word2vec` embeddings for about 15 thousand words. Not every word in each review is present in the provided `word2vec.txt` file. We can treat these words as being "out of vocabulary" and ignore them.
#
# ### Example
#
# Let x_i denote the sentence `“a hot dog is not a sandwich because it is not square”` and let a toy word2vec dictionary be as follows:
#
# ```
# hot      0.1     0.2     0.3
# not      -0.1    0.2     -0.3
# sandwich 0.0     -0.2    0.4
# square   0.2     -0.1    0.5
# ```
#
# we would first `trim` the sentence to only contain words in our vocabulary: `"hot not sandwich not square”` then embed x_i into the feature space:
#
# $$ φ2(x_i)) = \frac{1}{5} (word2vec(\text{hot}) + 2 · word2vec(\text{not}) + word2vec(\text{sandwich}) + word2vec(\text{square})) = \left[0.02 \hspace{2mm} 0.06 \hspace{2mm} 0.12 \hspace{2mm}\right]^T $$
#
# a) Implement a function to trim out-of-vocabulary words from the reviews. Your function should return an nd array of the same dimension and dtype as the original loaded dataset.

# %%
import csv
import numpy as np

VECTOR_LEN = 300   # Length of word2vec vector
MAX_WORD_LEN = 64  # Max word length in dict.txt and word2vec.txt

def load_tsv_dataset(file):
    """
    Loads raw data and returns a tuple containing the reviews and their ratings.

    Parameters:
        file (str): File path to the dataset tsv file.

    Returns:
        An np.ndarray of shape N. N is the number of data points in the tsv file.
        Each element dataset[i] is a tuple (label, review), where the label is
        an integer (0 or 1) and the review is a string.
    """
    dataset = np.loadtxt(file, delimiter='\t', comments=None, encoding='utf-8',
                         dtype='l,O')
    return dataset


def load_feature_dictionary(file):
    """
    Creates a map of words to vectors using the file that has the word2vec
    embeddings.

    Parameters:
        file (str): File path to the word2vec embedding file.

    Returns:
        A dictionary indexed by words, returning the corresponding word2vec
        embedding np.ndarray.
    """
    word2vec_map = dict()
    with open(file) as f:
        read_file = csv.reader(f, delimiter='\t')
        for row in read_file:
            word, embedding = row[0], row[1:]
            word2vec_map[word] = np.array(embedding, dtype=float)
    return word2vec_map


def trim_reviews(path_to_dataset):
    path_to_embeddings = "./data/word2vec.txt"
    
    # Load the dataset and word2vec embeddings using the specified paths
    dataset = load_tsv_dataset(path_to_dataset)
    word2vec_map = load_feature_dictionary(path_to_embeddings)
    
    trimmed_reviews = []

    for label, review in dataset:
        trimmed_review_words = []
        for word in review.split():
            if word in word2vec_map:
                trimmed_review_words.append(word)
        trimmed_review = " ".join(trimmed_review_words)
        trimmed_reviews.append((label, trimmed_review))
    
    return np.array(trimmed_reviews, dtype=dataset.dtype)

trim_train = trim_reviews("./data/train_small.tsv")
trim_test = trim_reviews("./data/test_small.tsv")

print(trim_train)
print(trim_test)
# Out:
# [(1, 'i will never forget this single breakfast experience in madison it was awesome yes it is crowded and you have to sit with other groups at the large tables yes you have to pay cash yes it seems like you are eating breakfast in your grandmother s kitchen but seriously i like my grandmother s kitchen it is quite the experience and totally worth the perceived the coffee was fresh and dark the chocolate was to die for and the fruit covered french toast made from was sinful if i ever find myself in madison again i will definitely go out of my way to return to this little gem of a breakfast')
#  (0, 'the search for decent chinese in madison continues the food at this place we ordered delivery is nothing worth waiting hours for egg rolls which contain nothing but lo they clearly do not understand how to work with nor do they get how to deliver quality food in a timely fashion the one plus was the were still just save your time and money and don t bother not even a good of can make their ho food the reviews i ve seen from in house do not provide any contrast to our delivery experience')
#  (0, 'sorry but me fell way below the standard for even mediocre food first what s up with the popcorn okay so it is a balance between mexican and american well maybe but t it so american to understand that you always get a of chips and a bowl of at an american mexican restaurant even my 11 year old grandson wondered about it without my first enough about the popcorn my son ordered a he said it was okay it was prepared opposite of what is typically expected the and on the inside the meat served over the top of the my daughter ordered chicken she had nothing good to say about the dish the chicken looked and as if it was prepared in a bag in a it was not hot when it was served the which we assumed was were awful no one could not tell what they were made from the beans had an extremely odd texture probably the worse plate of we have ever experienced my mom ordered french soup really what is french soup doing on this menu t matter but of course it received a mediocre rating as well she also had a she did not comment on it i ordered the with chicken cheese and dressing on the side of all the dishes served this was actually pretty good not excellent but good all in all we all agreed this was the last time we would be here we all agreed me s has been the worse mexican restaurant we have experienced')
#  (1, 'disclaimer came here for the night scene so i have no on the food came here around 11 on a saturday night and i had a blast wells mixed with good music soft lights and lots of people the drinks were just strong enough to be worth and the service was very quick impressive for on saturday the dance floor had four or five displaying the music videos of the song playing and the floor was pretty big there is a large couch the dance floor and there a quite a few tables i was very happy with this no cover and people were dressed in heels and ties seemed a little bit too good for a bar without cover and cheap drinks i plan on coming back on a different night am not sure if i got lucky or if madison s is the place i want to come back to every saturday night')
#  (1, 'so this is the kind of food that will kill you so there s that but that being said this is the best way i can think of to take in food with absolutely no value the are sweet tender meat bars the sides are sweet flavor bombs of flavor the rolls are airy balls of you should get extra i think this place is best for you can sit and eat there are a handful of tables but then there are also bullet holes in the windows since it s madison i m assuming someone put them there for show but definitely with a real gun so anyway i d rather eat at home also if you ve been doing the house of cards thing and want that experience but you don t live in the south this is the closest you are going to get so check it out madison it s a little bit different but that t mean it t fabulous')
#  (0, 'it s so sad that my third time coming here is not a good experience it was okay not fantastic when i came here for the first and second time but today when i was really craving for some i decided to have it here it is during the lunch time but the restaurant still has way too many empty seats the waitress speaks very limited english so i can t ask her for some explanation on some menu we were given two glasses of water one for me the other for my hubby just when i wanted to drink i was surprised to learn the glass is super dirty which made me think they t wash it i asked the waitress to change it and she t say sorry at all and it s been twenty minutes and more but i don t think our order will come soon and oh the seem to be regulars too for this place while the overall place is not dirty i was wondering why this place t mind having some flying around the customer s tables my hubby s thai tea came after 25 minutes we ordered our food i can t wait to write this review as i don t remember the last time i ever had a very bad experience with a restaurant won t be back soon maybe next year or so and we had to pay tips not included such a waste')
#  (0, 'this is horrible the owner is a cheap shrew and the food is even compared to her sister s fare at the close to campus the owner of this park st location i hear they have now moved to sherman i believe was arrogant about the fact that their pad thai tastes like ketchup unlike the pad thai at legitimate restaurants could this be a cheap to the use of and other the owner said that how we do it here we use ketchup she explained that the reason the other was different pad thai is that the other one is owned by her sister who does not use ketchup in the dish then the cheap woman accused us of merely not wanting to pay for the food when it was being sent back to the kitchen the sister at the by campus cannot smile to save her life and you will come out of there like their kitchen but the food is better so go there and get it for')
#  (1, 'oh my gosh this is the best place in madison i m from out of town and i got excited when my friend told me about it i m a breakfast gal and they serve breakfast all day here i was so happy i got the saturday special and fire pepper with two eggs over medium a side of bacon and amazing every bite was mouth see pictures my friends and i split a banana cream pie and it was also good every bite i wish i got my own slice i wanted to try everything on the menu friendly kid friendly milk shakes breakfast great music outdoor what more could you ask for with this diner service was also excellent enjoy')
#  (0, 'atmosphere very nice clean trendy however extremely loud they really need some sound inside service this was the best part our waitress was very attentive and friendly food on the average side for the price point i had the soup ok chop good but could have used some more flavor very good and sweet potato excellent flavor but a lot of butter drinks friend had the old fashioned which i am not sure why they don t make a style old fashion sad to say the glass was very small full of ice and not even filled to the top with the drink for was very disappointed won t be going back but i wish them the best of luck in a very tough market')
#  (1, 'looking for beer this is the best spot in town with hundreds of choices you not be for decision my favorites are like blue and fruit that taste like sparkling wine the local new beer is also really tasty are you hungry no worries this place is the best in town for double fried done right every single time as said by the boss also the and v burger is also a hit if you re just looking for bar food the are really tasty as well i also like the fries but if i had to pick the are my favorite they also often do alot of beer probably once a month very fun activity the space was recently expanded there s more bar space and a few more tables if you re there with just a friend sit at the bar they serve the full menu there as well if you wanna go there in a group it might be hard unless you re there before great beer and a great selection of french wine as well what more can you ask for')
#  (0, 'so we decided to a try and drinks were fine my dinner and my wife s dinner were luke warm at least our two other friends had hot food served to them took ten minutes to get our meals back the owner came over to apologize but the waiter never did when we got our bill which was good bill for i expected to see something knocked off the bill due to having to send the food back last time i eat there and besides this review i will let others to go to our favorite mexican place la or del instead la')
#  (0, 'this place is probably alright if you re there for a few drinks on a with some friends but don t come here for the food or service my took me here while we were visiting this past week because she used to come here often when she lived in madison i expected a decent meal i ordered the chop special and it was both and horribly lacking on meat i sent it back and ordered the which was horribly no deal discount on the meal either which any decent restaurant would at least offer if they wanted your repeat business the waitress admitted that the chop was the worst she d ever seen lame tell the cook then and have the manager work on that poorly managed place with sub par service staff definitely won t be coming back here')
#  (0, 'is the perfect for we went with a group of friends of whom had been at the old location i have no complaints about the and really none about service neither stood out for good or bad reasons the food yeah the pizza was okay and yes i am aware this t supposed to be american pizza i ve tried pizza all over the globe and like each variation for its own reasons even my husband who will pretty much eat anything and at least say it was okay was pretty about it i had a special dish just based on that i would give a however because it s not a normal option and what i tried of my companions food was also it s not enough to raise the overall score upon leaving the restaurant my husband and i immediately named this a we won t pick this restaurant again but won t throw a huge fit if a group of friends want to go place thankfully we haven t had to go back')
#  (0, 'the two stars is for the food we had and my grandson had and cheese both delicious apparently the host had to host wait on tables and cook if you can t remember the order you should write it down ordered waited a very long time for our meals brought them out no told him to forget it half way through meal had to ask for bread which was suppose to come with the meal it was a terrible experience especially with a year old if your sign says open please have enough staff to your customers very poor management i go down the street to next time')
#  (1, 'i stopped here while on a road trip to for a bite and a brief by the highway signs this was the only place listed that was not a chain it s a couple miles off the road but easy to get to and easy to get back from i tried a beer it was good if perhaps a tiny bit more bitter on the finish than i m used to had a red which he thought was good he ordered the da as he was not terribly hungry joke was on him it was huge it was bigger than a small pizza it was pounds of goodness it came with two different and a cheese the were good the was amazing but the cheese was the generic day glow yellow crap he also had a cup of beer cheese soup unusual in that it contained he said it was okay but the addition was a bit odd i had cheese as we d recently crossed the border into and they were calling to me a former native they were good but not amazing they make the white variety and serve them with a sweet this was a good spot and a nice stop from the road')
#  (1, 'we had a large group at on a evening and were able to secure the private room upstairs which seats about a bit under 20 we got a set menu that included several options for each course i opted for the soup which was amazing it had a hint of cream in it which gave it a texture for my main i had the which was well and came with some nice except they t have the chocolate desert was like and a nice way to close out the evening the wine and beer list is pretty and includes variety in both type and price if you re in the madison area this is worth a stop after or before dinner there a few bars close by but you can also around the capital building and work off your meal this place is far enough away from state street that it t get to wild which makes it nice for a business meal or date night')
#  (1, 'this place is perfect if i lived anywhere nearby i d come all the time great alcohol selection great good live music and all really reasonably beer wise not only is their selection really extensive but you have the option to get most of the draft in smaller sizes to get a wider sample one of my favorite at any bar the burger was huge and delicious perfectly the take on a huge number of tables but are super efficient checking in with you exactly when you need them and not when you don t music wise don t worry that you re going to miss the start the band had just started to play at 10 and was at least an hour late that said we barely got a table at 10 so you might need to come early to grab at seat at this amazing bar')
#  (0, 'i ve heard people rave about brazilian and i finally went with high hopes but left really quite disappointed my overall impression is that is a and other assorted but a pain in the ass because you have to wait for someone to come by and cut off an portion of meat and you pay through the nose for it the taste of some of the food is ok you start with a of i got some chicken not good good but you can get them anywhere in the area for cheap and cheese filled rolls excellent but you should probably not fill up too much since the real experience is in the and that the bring to your table at you flip a big red green plastic thing to indicate when you want food if you have it green side up then will come by your table and cut off a piece of meat or and so on until you flip your thing back over to red so you can eat the was quite good the leg of was well but the meat was a bit too for my liking the top was disappointing as hell there were a couple decent bites but the i got were mostly and some pieces were loaded with the has and sugar and just tastes like warm with and sugar assuming you get a piece with and sugar on it which only outside pieces have i was greatly disappointed by a few of the like and honey chicken with the exception of the which was quite good but not special i was overall pretty disappointed i am not brazilian and am not an expert but i have had brazilian food before if you t tell me that was brazilian i would never have guessed it was supposed to be critically are like the drink of brazil and the one i had at was the worst one i ever had that s disappointing since they re one of my favorite the service was we were there at a on they open at and the place t getting full until we just about finished our meal but it still took forever for our drinks to get get our bill etc i don t blame our waitress so much it seemed like she just had a lot of tables to take care of i think if you re 37 or whatever a plate you can afford to hire adequate staff overall as many other reviewers have already said the quality of food does not justify the price my fiance and i had two two and a fountain drink which cost us over 100 and it was in no way worth 100 let alone even half that if i were to ignore the price i d give stars but i can t rate them at any more than given the high price for pedestrian food')
#  (1, 'first time in a which witch and i was surprised efficient and interesting set up with reasonable prices this chain had the as a special and it was way better than i expected it to be i usually get mine from legitimate stores and i was expecting this one to be a huge let down especially since it s a white chain racist maybe sorry not sure maybe if i have to ask it is yes the is a little different than the original and it s missing the but seriously a solid variation definitely would come again')
#  (1, 'the burger with ketchup is by far the best thing on the lunch and dinner menu always has great on tap and plenty of variety in menu offerings it is well known that folks in the area go for half price happy hour although tonight we went at typical happy hour time and we did not receive happy hour prices this is the main reason we go prior to and will continue to visit regardless of happy hour deals but this is a nice needless to say we will be back but we will also select a different spot for post work drinks since their deals have become unclear')]
# [(0, 'i got the virus from this place not having a enough bar and was throwing up so much the next day that i needed to get an iv injected into me at the student health center i have had much better experiences in there in the past and the food is undoubtedly very tasty however after almost having to get an because i was so drained from food the virus the serve yourself bar atmosphere suddenly lost the all you eat appeal and was replaced with a of a slightly version of an all you can eat las vegas strip club with less of the grotesque entertainment but all of the who needs a walk up style menu any ways last time i had that was at a breakfast at a hotel i should have kept it that way')
#  (0, 'we came for the live music which was great i love that they have bands there on the but the food and drinks t great i had a which was way too sweet i sent it back and they it the same they are mixed so there s no room for change the thing is in madison there s an incredible craft cocktail scene so the competition is stiff and many of us don t want an overly sweet mixed drink but a the chips and were also mediocre compared to places like s i d try it one more time for dinner in a perhaps after they ve had a little more time to grow')
#  (1, 'i arrived at oliver s quite skeptical a review of their website had turned up a 14 dollar children s which struck me as crazy and but we left the kids at home and had a lovely meal i think now that might be a ploy to keep the numbers of kids low which is fine the cocktail menu is a delight to read with inventive twists on standards the beer selection is very solid all our dishes were delightful my was absolutely delicious a companion was pleased with the another dinner found the special to be a little overly i want to make special mention of how wonderful the service was our waiter was familiar and confident with the food and drink he by the of the table to see if we needed anything but never once interrupted the flow of our conversation that is so incredibly rare these days oliver you won me over we be back')
#  (1, 'i ve been anticipating the opening of the new place since i read about its having studied the history of ancient japanese art culture in college has made me a bit of a due to the subtle approach they take in all things beautiful and pulls this off my daughter and i went there for lunch and sat next to the in the near the entrance good for a escape route with an almost year old we were greeted right away and made to feel welcome we choose one of three lunch combination options the with soup other choices include chicken and and the chicken and for ten bucks other choices are chicken and they were nice enough to bring us that t on the menu the soup was out of sight although i wish it were hot i know that is to a which survives to be the most at a certain temperature the noodles were perfect the in my mouth i had to ask about the egg which was quite honestly a turn on an almost hard boiled chicken egg with a center but not it had a dark liquid running through it which the waiter t explain to me which brings me to the service of is still working out the of what a new restaurant brings and i understand that so i can overlook the waiter not knowing how to describe something especially when it s so damn good but what s hard to comprehend is the counter service in a day and age where people don t have money to tip but still want to out a lot of counter service have up but lends itself to table service i don t want my or soup to get cold while i go up to order another sake and even more important i might not order another sake because i have to get up and leave my food and my experience the experience is lovely here with wall accents of ripe and colors and the bar with inspired the place is simple and sophisticated with and great music and lighting it s just so wonderful that i want someone to bring me my drink so that i can take it all in and not put it on pause i dream of going back without a child to get a buzz that only good sake can give and to try the tuna and the belly with')
#  (0, 'the was good we were the only ones there and the rice was overdone and the chicken was my least favorite chicken i have ever had along with my partner s dish there was very very little meat the were way off it was far more than i enjoy it t the warm comforting feeling i get when i eat s chicken this was some thin pieces of chicken in a kind of odd mess i was going to give this place two stars but the hair i got in my chicken and the hair my partner got in his made me think it over')
#  (1, 'i definitely enjoyed my here this afternoon i had the and it was damn delicious anything with on it i have to try and i am so glad i did it came on toast with cream cheese and very my girlfriends tried the burger and the french soup and said it hit the spot decent service for the most part and the food came out quickly which i always like it was a nice enough day so we on the i t get much of a chance to check out the inside but i would like to see more of it next time i like that this place is a little bit off state street because its close enough that you can be part of the party but also not in the way of anyone you don t have to deal with drunk people stumbling around your food or too much they have cute flower on the tables as well as candles')
#  (1, 'i was in town to visit my daughter and here several times while staying at the just the fact that the hotel is attached to bassett street club makes it the best hotel in the world but enough about them i can t say enough about this place i had the best i ve ever eaten loved the breakfast items and the m f happy hour great pours at great prices i always said i would go back but now i want to move into the place my daughter was pretty sick recently and t get up off the couch they in to the rescue and brought her soup even though they don t deliver and t really set up to do so the best people running a great business and going out of their way to help i m a huge fan of them and their french toast')
#  (0, 'went for lunch we both ordered portions price amount of ingredients were all good but the of is the there was no star flavor to be found i added all the then and finally looking for flavor i told myself the thought of the bowl in front of me as and just eat the noodles and i overlooked the dirty looking exterior when entering but started to look around a bit more closely when the disappointed the wall paint was on both sides of the booth as well as in many other areas of the restaurant and the window area as we was disgustingly dirty that makes me question the condition of the kitchen we will never return based on food and certainly the atmosphere')]
